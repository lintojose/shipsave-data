# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dftest = pd.read_csv("ship test.csv")
dftrain = pd.read_csv("ship train.csv")

dftest.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dftrain.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1=dftrain[['Name','Sex','Age']]
df1
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
dfmrs=df1[df1['Name'].str.contains("Mrs.","Ms.")]
dfmrs
# Out:
#                                                   Name     Sex   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ..                                                 ...     ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
#
# [129 rows x 3 columns]

# %%
dfmrsmean=dfmrs.mean()
dfmrsmean
# Out:
# Age    35.642857
# dtype: float64

# %%
mrsfilled = dfmrs.fillna(dfmrsmean)
mrsfilled
# Out:
#                                                   Name     Sex   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ..                                                 ...     ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
#
# [129 rows x 3 columns]

# %%
dfMiss=df1[df1['Name'].str.contains("Miss")]
dfMiss
# Out:
#                                          Name     Sex   Age
# 2                      Heikkinen, Miss. Laina  female  26.0
# 10            Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                   Bonnell, Miss. Elizabeth  female  58.0
# 14       Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 22                McGowan, Miss. Anna "Annie"  female  15.0
# ..                                        ...     ...   ...
# 866              Duran y More, Miss. Asuncion  female  27.0
# 875          Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 882              Dahlberg, Miss. Gerda Ulrika  female  22.0
# 887              Graham, Miss. Margaret Edith  female  19.0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
# [182 rows x 3 columns]

# %%
dfmissmean=dfMiss.mean()
dfmissmean
# Out:
# Age    21.773973
# dtype: float64

# %%
misfilled = dfMiss. fillna(dfmissmean)
misfilled
# Out:
#                                          Name     Sex        Age
# 2                      Heikkinen, Miss. Laina  female  26.000000
# 10            Sandstrom, Miss. Marguerite Rut  female   4.000000
# 11                   Bonnell, Miss. Elizabeth  female  58.000000
# 14       Vestrom, Miss. Hulda Amanda Adolfina  female  14.000000
# 22                McGowan, Miss. Anna "Annie"  female  15.000000
# ..                                        ...     ...        ...
# 866              Duran y More, Miss. Asuncion  female  27.000000
# 875          Najib, Miss. Adele Kiamie "Jane"  female  15.000000
# 882              Dahlberg, Miss. Gerda Ulrika  female  22.000000
# 887              Graham, Miss. Margaret Edith  female  19.000000
# 888  Johnston, Miss. Catherine Helen "Carrie"  female  21.773973
#
# [182 rows x 3 columns]

# %%
dfMaster=df1[df1['Name'].str.contains("Master")]
dfMaster
# Out:
#                                                   Name   Sex    Age
# 7                       Palsson, Master. Gosta Leonard  male   2.00
# 16                                Rice, Master. Eugene  male   2.00
# 50                          Panula, Master. Juha Niilo  male   7.00
# 59                  Goodwin, Master. William Frederick  male  11.00
# 63                               Skoog, Master. Harald  male   4.00
# 65                            Moubarek, Master. Gerios  male    NaN
# 78                       Caldwell, Master. Alden Gates  male   0.83
# 125                       Nicola-Yarred, Master. Elias  male  12.00
# 159                         Sage, Master. Thomas Henry  male    NaN
# 164                       Panula, Master. Eino Viljami  male   1.00
# 165    Goldsmith, Master. Frank John William "Frankie"  male   9.00
# 171                               Rice, Master. Arthur  male   4.00
# 176                      Lefebre, Master. Henry Forbes  male    NaN
# ...

# %%
dfMastermean=dfMaster.mean()
dfMastermean
# Out:
# Age    4.574167
# dtype: float64

# %%
masterfilled = dfMaster. fillna(dfMastermean)
masterfilled
# Out:
#                                                   Name   Sex        Age
# 7                       Palsson, Master. Gosta Leonard  male   2.000000
# 16                                Rice, Master. Eugene  male   2.000000
# 50                          Panula, Master. Juha Niilo  male   7.000000
# 59                  Goodwin, Master. William Frederick  male  11.000000
# 63                               Skoog, Master. Harald  male   4.000000
# 65                            Moubarek, Master. Gerios  male   4.574167
# 78                       Caldwell, Master. Alden Gates  male   0.830000
# 125                       Nicola-Yarred, Master. Elias  male  12.000000
# 159                         Sage, Master. Thomas Henry  male   4.574167
# 164                       Panula, Master. Eino Viljami  male   1.000000
# 165    Goldsmith, Master. Frank John William "Frankie"  male   9.000000
# 171                               Rice, Master. Arthur  male   4.000000
# ...

# %%
combine1=pd.concat(['mrsfilled','misfilled','masterfilled'], axis=0) 
combine1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-35077e1b7d2e> in <module>
# ----> 1 combine1=pd.concat(['mrsfilled','misfilled','masterfilled'], axis=0)
#       2 combine1
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
#     372             # consolidate
#
# ...
